# %%
import sktime

# %%
from sktime import datasets

# %%
airline = datasets.load_airline()

# %%
airline
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
#       ...
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: Airline, Length: 144, dtype: int64

# %%
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.forecasting.naive import NaiveForecaster

# %%
y_train, y_test = temporal_train_test_split(airline, test_size=36)

# %%
forecaster = NaiveForecaster(strategy="mean")

# %%
len(y_train)
# Out:
# 108

# %%
fh = list(range(1,37))

# %%
forecaster.fit(y_train)
# Out:
# NaiveForecaster(strategy='mean')

# %%
y_pred = forecaster.predict(fh)

# %%
from sktime.utils.plotting.forecasting import plot_ys

# %%
import matplotlib.pyplot as plt

# %%
plot_ys(y_train, y_test, y_pred, labels = ["Train", "Test", "Pred"])
# Out:
# (<Figure size 1152x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x192e85910b8>)

# %%
forecaster = NaiveForecaster(strategy="seasonal_last", sp = 10)
forecaster.fit(y_train)
y_pred = forecaster.predict(fh)
plot_ys(y_train, y_test, y_pred, labels = ["Train", "Test", "Pred"])
# Out:
# (<Figure size 1152x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x192e8761cc0>)

# %%
forecaster = NaiveForecaster(strategy="seasonal_last", sp = 12)
forecaster.fit(y_train)
y_pred = forecaster.predict(fh)
plot_ys(y_train, y_test, y_pred, labels = ["Train", "Test", "Pred"])
# Out:
# (<Figure size 1152x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x192e8643048>)

# %%
forecaster = NaiveForecaster(strategy="seasonal_last", sp = 12)
forecaster.fit(y_train)
y_pred = forecaster.predict(fh)
plot_ys(y_train, y_test, y_pred, labels = ["Train", "Test", "Pred"])
# Out:
# (<Figure size 1152x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x192e87fec88>)

# %% [markdown]
# # Time series Data
# ## Univariate = One variable at a time for different time periods
# ## Multivariate = Mutiple variable at a time for different time
