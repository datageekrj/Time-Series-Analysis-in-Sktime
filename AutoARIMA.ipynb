# %%
from sktime.forecasting.arima import AutoARIMA
# Out:
# C:\Users\rahul\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\rahul\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
from sktime.datasets import load_airline

# %%
airline = load_airline()

# %%
from sktime.utils.plotting.forecasting import plot_ys

# %%
import matplotlib.pyplot as plt

# %%
plot_ys(airline)
# Out:
# (<Figure size 1152x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1a29b0f69e8>)

# %%
from sktime.forecasting.model_selection import temporal_train_test_split

# %%
y_train, y_test = temporal_train_test_split(airline, test_size=36)

# %%
fh = list(range(1,37))

# %%
forecaster = AutoARIMA()
# Out:
# C:\Users\rahul\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
forecaster.fit(y_train)
# Out:
# C:\Users\rahul\Anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:975: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\rahul\Anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\rahul\Anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# AutoARIMA()

# %%
y_pred = forecaster.predict(fh)

# %%
plot_ys(y_train, y_test, y_pred, labels = ["Train", "Test", "Pred"])
# Out:
# (<Figure size 1152x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1a2a03a32b0>)
