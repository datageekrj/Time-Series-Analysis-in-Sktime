# %%
from sktime.utils.plotting.forecasting import plot_ys
from sktime.datasets import load_airline
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.performance_metrics.forecasting import smape_loss
import matplotlib.pyplot as plt

# %%
from sktime.forecasting.exp_smoothing import ExponentialSmoothing

# %%
airline = load_airline()
train, test = temporal_train_test_split(airline, test_size = 36)

# %%
fh = list(range(1,37))

# %%
simple_exp = ExponentialSmoothing(trend=None, seasonal=None)

# %%
simple_exp.fit(train)
# Out:
# ExponentialSmoothing()

# %%
pred = simple_exp.predict(fh)

# %%
pred
# Out:
# 108    336.0
# 109    336.0
# 110    336.0
# 111    336.0
# 112    336.0
# 113    336.0
# 114    336.0
# 115    336.0
# 116    336.0
# 117    336.0
# 118    336.0
# 119    336.0
# 120    336.0
# 121    336.0
# 122    336.0
# 123    336.0
# 124    336.0
# 125    336.0
# 126    336.0
# 127    336.0
# 128    336.0
# 129    336.0
# 130    336.0
# 131    336.0
# 132    336.0
# 133    336.0
# 134    336.0
# 135    336.0
# 136    336.0
# 137    336.0
# 138    336.0
# 139    336.0
# 140    336.0
# 141    336.0
# 142    336.0
# 143    336.0
# dtype: float64

# %%
plot_ys(train, test, pred, labels = ["train", "test", "pred"])
# Out:
# (<Figure size 1152x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x228f5be47b8>)

# %%
double_exp = ExponentialSmoothing(trend="add", seasonal=None)

# %%
double_exp.fit(train)
# Out:
# ExponentialSmoothing(trend='add')

# %%
pred = double_exp.predict(fh)

# %%
pred
# Out:
# 108    338.093449
# 109    340.186897
# 110    342.280346
# 111    344.373795
# 112    346.467243
# 113    348.560692
# 114    350.654141
# 115    352.747589
# 116    354.841038
# 117    356.934487
# 118    359.027935
# 119    361.121384
# 120    363.214833
# 121    365.308281
# 122    367.401730
# 123    369.495179
# 124    371.588627
# 125    373.682076
# 126    375.775525
# 127    377.868973
# 128    379.962422
# 129    382.055871
# 130    384.149319
# 131    386.242768
# 132    388.336217
# 133    390.429665
# 134    392.523114
# 135    394.616563
# 136    396.710011
# 137    398.803460
# 138    400.896909
# 139    402.990357
# 140    405.083806
# 141    407.177255
# 142    409.270703
# 143    411.364152
# dtype: float64

# %%
plot_ys(train, test, pred, labels = ["train", "test", "pred"])
# Out:
# (<Figure size 1152x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x228f5d89cf8>)

# %%
triple_Exp = ExponentialSmoothing(trend="add", seasonal="add", sp=12)

# %%
triple_Exp.fit(train)
# Out:
# C:\Users\rahul\Anaconda3\lib\site-packages\statsmodels\tsa\holtwinters.py:744: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning)
# ExponentialSmoothing(seasonal='add', sp=12, trend='add')

# %%
pred = triple_Exp.predict(fh)

# %%
plot_ys(train, test, pred, labels = ["train", "test", "pred"])
# Out:
# (<Figure size 1152x288 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x228f85e6ac8>)
